# %% [markdown]
# # Segmenting and Clustering Neighborhoods in Dallas
# By Alex P. Blizzard

# %% [markdown]
# ## Data Preprocessing

# %%
# Import libraries
import pandas as pd
import numpy as np
import requests
import os
from sklearn.cluster import KMeans
import folium 
# !conda install -c conda-forge geopy --yes
from geopy.geocoders import Nominatim 
import matplotlib.cm as cm
import matplotlib.colors as colors
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /home/jupyterlab/conda/envs/python
#
#   added / updated specs:
#     - geopy
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     geographiclib-1.50         |             py_0          34 KB  conda-forge
#     geopy-1.22.0               |     pyh9f0ad1d_0          63 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:          97 KB
#
# The following NEW packages will be INSTALLED:
#
#   geographiclib      conda-forge/noarch::geographiclib-1.50-py_0
#   geopy              conda-forge/noarch::geopy-1.22.0-pyh9f0ad1d_0
#
#
#
# Downloading and Extracting Packages
# geopy-1.22.0         | 63 KB     | ##################################### | 100%
# geographiclib-1.50   | 34 KB     | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %%
#Import  Dallas data
dallas_df = pd.read_csv('Dallas_Data.csv')
print('Dallas data read successfully!')
dallas_df.set_index('Neighborhood')
# Out:
# Dallas data read successfully!
#                                  Latitude  Longitude
# Neighborhood
# Baylor District                 32.797826 -96.778186
# The Cedars                      32.769897 -96.785852
# Civic Center District           32.776255 -96.798500
# Dallas Arts District            32.788885 -96.798924
# Dallas Farmers Market           32.778543 -96.788246
# Deep Ellum                      32.784001 -96.778559
# Design District                 32.789055 -96.821590
# Main Street District            32.780931 -96.798114
# Reunion District                32.773613 -96.807676
# Riverfront District             32.768468 -96.812929
# South Side                      32.765736 -96.794980
# Thanksgiving Commercial Center  32.784866 -96.796783
# Uptown                          32.802121 -96.800784
# Victory Park                    32.788206 -96.810155
# West End Historic District      32.780877 -96.807525

# %%
# Create map of downtown Dallas
map_dallas = folium.Map(location=[32.7791, -96.8003], zoom_start=13)
for lat, lng, label in zip(dallas_df['Latitude'], dallas_df['Longitude'], \
dallas_df['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_dallas)  
    
map_dallas
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Define Foursquare credientials
CLIENT_ID = 'UXIK2GMZJZPTNAV4P5XYRUFRJIK2BDHKBUAAYV4HRBQVLRLI' # your Foursquare ID
CLIENT_SECRET = '35SMWRDEEFGMXGSVETWBVLNKMZWRUQSXMU4MZLSFD430SZZL' # your Foursquare Secret
VERSION = '20180604'

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: UXIK2GMZJZPTNAV4P5XYRUFRJIK2BDHKBUAAYV4HRBQVLRLI
# CLIENT_SECRET:35SMWRDEEFGMXGSVETWBVLNKMZWRUQSXMU4MZLSFD430SZZL

# %%
#Define API from Foursquare
LIMIT = 100
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
        
        results = requests.get(url).json()["response"]['groups'][0]['items']
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

#Get nearby venues in Dallas
dallas_venues = getNearbyVenues(names=dallas_df['Neighborhood'],
latitudes=dallas_df['Latitude'], longitudes=dallas_df['Longitude'])
dallas_venues.groupby('Neighborhood').count()
# Out:
# Baylor District
# The Cedars
# Civic Center District
# Dallas Arts District
# Dallas Farmers Market
# Deep Ellum
# Design District
# Main Street District
# Reunion District
# Riverfront District
# South Side
# Thanksgiving Commercial Center
# Uptown
# Victory Park
# West End Historic District
#                                 Neighborhood Latitude  Neighborhood Longitude  \
# Neighborhood
# Baylor District                                    27                      27
# Civic Center District                              28                      28
# Dallas Arts District                               37                      37
# Dallas Farmers Market                              21                      21
# Deep Ellum                                         50                      50
# Design District                                    23                      23
# Main Street District                              100                     100
# Reunion District                                   22                      22
# Riverfront District                                 6                       6
# South Side                                         25                      25
# Thanksgiving Commercial Center                     49                      49
# The Cedars                                         12                      12
# Uptown                                             40                      40
# Victory Park                                       31                      31
# West End Historic District                         57                      57
#
#                                 Venue  Venue Latitude  Venue Longitude  \
# Neighborhood
# Baylor District                    27              27               27
# Civic Center District              28              28               28
# Dallas Arts District               37              37               37
# Dallas Farmers Market              21              21               21
# Deep Ellum                         50              50               50
# Design District                    23              23               23
# Main Street District              100             100              100
# Reunion District                   22              22               22
# Riverfront District                 6               6                6
# South Side                         25              25               25
# Thanksgiving Commercial Center     49              49               49
# The Cedars                         12              12               12
# Uptown                             40              40               40
# Victory Park                       31              31               31
# West End Historic District         57              57               57
#
#                                 Venue Category
# Neighborhood
# Baylor District                             27
# Civic Center District                       28
# Dallas Arts District                        37
# Dallas Farmers Market                       21
# Deep Ellum                                  50
# Design District                             23
# Main Street District                       100
# Reunion District                            22
# Riverfront District                          6
# South Side                                  25
# Thanksgiving Commercial Center              49
# The Cedars                                  12
# Uptown                                      40
# Victory Park                                31
# West End Historic District                  57

# %% [markdown]
# ## Data Processing

# %%
#Analyzing each neighborhood
dallas_onehot = pd.get_dummies(dallas_venues[['Venue Category']], prefix="", prefix_sep="")
dallas_onehot['Neighborhood'] = dallas_venues['Neighborhood'] 
fixed_columns = [dallas_onehot.columns[-1]] + list(dallas_onehot.columns[:-1])
dallas_onehot = dallas_onehot[fixed_columns]

#Group average Neighborhood
dallas_grouped = dallas_onehot.groupby('Neighborhood').mean().reset_index()

#5 most common venues
num_top_venues = 10
for hood in dallas_grouped['Neighborhood']:
    print("----"+hood+"----")
    temp = dallas_grouped[dallas_grouped['Neighborhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Baylor District----
#                 venue  freq
# 0         Pizza Place  0.11
# 1      Discount Store  0.07
# 2  Mexican Restaurant  0.07
# 3      Sandwich Place  0.07
# 4          Taco Place  0.07
# 5   Convenience Store  0.04
# 6         Supermarket  0.04
# 7        Dance Studio  0.04
# 8          Donut Shop  0.04
# 9         Coffee Shop  0.04
#
#
# ----Civic Center District----
#                 venue  freq
# 0               Hotel  0.18
# 1                Café  0.07
# 2               Plaza  0.07
# 3                 Bar  0.07
# 4         Coffee Shop  0.07
# 5         IT Services  0.04
# 6  Mexican Restaurant  0.04
# 7   Indian Restaurant  0.04
# 8   Mobile Phone Shop  0.04
# 9           Gift Shop  0.04
#
#
# ----Dallas Arts District----
#                      venue  freq
# 0               Food Truck  0.11
# 1    Performing Arts Venue  0.08
# 2               Steakhouse  0.08
# 3                  Theater  0.05
# 4      American Restaurant  0.05
# 5               Art Museum  0.05
# 6      Japanese Restaurant  0.05
# 7                      Gym  0.03
# 8  New American Restaurant  0.03
# 9              Opera House  0.03
#
#
# ----Dallas Farmers Market----
#                   venue  freq
# 0   American Restaurant  0.10
# 1        Farmers Market  0.10
# 2            Food Truck  0.10
# 3         Garden Center  0.05
# 4                  Pool  0.05
# 5               Dog Run  0.05
# 6           Coffee Shop  0.05
# 7        Clothing Store  0.05
# 8        Sandwich Place  0.05
# 9  Caribbean Restaurant  0.05
#
#
# ----Deep Ellum----
#                  venue  freq
# 0                  Bar  0.08
# 1            BBQ Joint  0.06
# 2          Music Venue  0.06
# 3  American Restaurant  0.04
# 4             Dive Bar  0.04
# 5         Dessert Shop  0.04
# 6          Coffee Shop  0.04
# 7   Mexican Restaurant  0.04
# 8          Art Gallery  0.04
# 9           Food Truck  0.02
#
#
# ----Design District----
#                     venue  freq
# 0             Art Gallery  0.22
# 1            Antique Shop  0.13
# 2  Furniture / Home Store  0.13
# 3      Mexican Restaurant  0.09
# 4       Convenience Store  0.04
# 5    Gym / Fitness Center  0.04
# 6              Print Shop  0.04
# 7             Pizza Place  0.04
# 8          Shipping Store  0.04
# 9             Bridal Shop  0.04
#
#
# ----Main Street District----
#                 venue  freq
# 0               Hotel  0.10
# 1         Coffee Shop  0.09
# 2      Sandwich Place  0.05
# 3  Mexican Restaurant  0.05
# 4                 Bar  0.04
# 5        Cocktail Bar  0.04
# 6                Park  0.03
# 7          Sports Bar  0.03
# 8         Salad Place  0.03
# 9                Café  0.03
#
#
# ----Reunion District----
#                  venue  freq
# 0                Hotel  0.14
# 1  American Restaurant  0.09
# 2       Scenic Lookout  0.09
# 3           Steakhouse  0.05
# 4   Italian Restaurant  0.05
# 5         Intersection  0.05
# 6    French Restaurant  0.05
# 7           Food Truck  0.05
# 8                 Park  0.05
# 9          Event Space  0.05
#
#
# ----Riverfront District----
#                    venue  freq
# 0           Liquor Store  0.33
# 1                Gay Bar  0.17
# 2       Business Service  0.17
# 3              BBQ Joint  0.17
# 4              Nightclub  0.17
# 5    American Restaurant  0.00
# 6            Opera House  0.00
# 7                   Park  0.00
# 8  Performing Arts Venue  0.00
# 9              Pet Store  0.00
#
#
# ----South Side----
#                  venue  freq
# 0          Music Venue  0.16
# 1                  Bar  0.08
# 2  American Restaurant  0.04
# 3     Business Service  0.04
# 4                Hotel  0.04
# 5                  Gym  0.04
# 6  Fried Chicken Joint  0.04
# 7    French Restaurant  0.04
# 8              Dog Run  0.04
# 9                  Pub  0.04
#
#
# ----Thanksgiving Commercial Center----
#                       venue  freq
# 0        Italian Restaurant  0.06
# 1              Cocktail Bar  0.06
# 2                     Hotel  0.06
# 3               Coffee Shop  0.06
# 4                       Gym  0.06
# 5                Steakhouse  0.06
# 6            Sandwich Place  0.04
# 7                Taco Place  0.04
# 8  Mediterranean Restaurant  0.04
# 9   New American Restaurant  0.04
#
#
# ----The Cedars----
#             venue  freq
# 0      Skate Park  0.17
# 1          Museum  0.08
# 2     Art Gallery  0.08
# 3     Coffee Shop  0.08
# 4        Pharmacy  0.08
# 5       BBQ Joint  0.08
# 6  History Museum  0.08
# 7      Food Court  0.08
# 8  Sandwich Place  0.08
# 9        Dive Bar  0.08
#
#
# ----Uptown----
#                  venue  freq
# 0         Cocktail Bar  0.10
# 1                  Bar  0.10
# 2          Pizza Place  0.08
# 3   Seafood Restaurant  0.08
# 4   Italian Restaurant  0.05
# 5                 Café  0.05
# 6                  Gym  0.05
# 7  American Restaurant  0.02
# 8     Sushi Restaurant  0.02
# 9           Restaurant  0.02
#
#
# ----Victory Park----
#               venue  freq
# 0            Lounge  0.06
# 1               Bar  0.06
# 2        Sports Bar  0.06
# 3        Restaurant  0.06
# 4      Cocktail Bar  0.03
# 5       Salad Place  0.03
# 6  Ramen Restaurant  0.03
# 7             Plaza  0.03
# 8       Pizza Place  0.03
# 9          Pharmacy  0.03
#
#
# ----West End Historic District----
#                 venue  freq
# 0      History Museum  0.07
# 1      Sandwich Place  0.05
# 2               Plaza  0.05
# 3               Hotel  0.05
# 4         Music Venue  0.05
# 5            Pharmacy  0.04
# 6           Gift Shop  0.04
# 7         Coffee Shop  0.04
# 8   Convenience Store  0.04
# 9  Italian Restaurant  0.04

# %%
#Define and sort 10 most common venues
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]
num_top_venues = 10
indicators = ['st', 'nd', 'rd']

#Create columns according to number of top venues
columns = ['Neighborhood']
for ind in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
    except:
        columns.append('{}th Most Common Venue'.format(ind+1))

#Create a new dataframe of sorted neighborhoods
neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighborhood'] = dallas_grouped['Neighborhood']

for ind in np.arange(dallas_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[ind, 1:] = return_most_common_venues(dallas_grouped.iloc[ind, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#             Neighborhood 1st Most Common Venue  2nd Most Common Venue  \
# 0        Baylor District           Pizza Place         Discount Store
# 1  Civic Center District                 Hotel            Coffee Shop
# 2   Dallas Arts District            Food Truck  Performing Arts Venue
# 3  Dallas Farmers Market   American Restaurant         Farmers Market
# 4             Deep Ellum                   Bar              BBQ Joint
#
#   3rd Most Common Venue  4th Most Common Venue 5th Most Common Venue  \
# 0        Sandwich Place     Mexican Restaurant            Taco Place
# 1                   Bar                   Café                 Plaza
# 2            Steakhouse    American Restaurant   Japanese Restaurant
# 3            Food Truck  Vietnamese Restaurant                  Pool
# 4           Music Venue    American Restaurant    Mexican Restaurant
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0         Grocery Store     Mobile Phone Shop            Donut Shop
# 1           IT Services    Seafood Restaurant           Salad Place
# 2            Art Museum               Theater        Sandwich Place
# 3          Dessert Shop        Sandwich Place               Dog Run
# 4          Dessert Shop              Dive Bar           Coffee Shop
#
#   9th Most Common Venue 10th Most Common Venue
# 0            Nail Salon   Fast Food Restaurant
# 1          Cocktail Bar       Department Store
# 2    Seafood Restaurant                Dog Run
# 3           Coffee Shop          Design Studio
# 4           Art Gallery            Pizza Place

# %% [markdown]
# ## Data Modeling

# %%
#Clustering Dallas venues data
kclusters = 5
dallas_grouped_clustering = dallas_grouped.drop('Neighborhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(dallas_grouped_clustering)
kmeans.labels_[0:10] 
neighborhoods_venues_sorted.insert(0, 'Cluster Labels2', kmeans.labels_)
dallas_merged = dallas_df

# Merge Dallas data
dallas_merged = dallas_merged.join(neighborhoods_venues_sorted.set_index('Neighborhood'), on='Neighborhood')
dallas_merged.head()
# Out:
#             Neighborhood   Latitude  Longitude  Cluster Labels2  \
# 0        Baylor District  32.797826 -96.778186                4
# 1             The Cedars  32.769897 -96.785852                0
# 2  Civic Center District  32.776255 -96.798500                4
# 3   Dallas Arts District  32.788885 -96.798924                1
# 4  Dallas Farmers Market  32.778543 -96.788246                1
#
#   1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 0           Pizza Place         Discount Store        Sandwich Place
# 1            Skate Park             Food Court                Museum
# 2                 Hotel            Coffee Shop                   Bar
# 3            Food Truck  Performing Arts Venue            Steakhouse
# 4   American Restaurant         Farmers Market            Food Truck
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0     Mexican Restaurant            Taco Place         Grocery Store
# 1         History Museum           Art Gallery           Coffee Shop
# 2                   Café                 Plaza           IT Services
# 3    American Restaurant   Japanese Restaurant            Art Museum
# 4  Vietnamese Restaurant                  Pool          Dessert Shop
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 0     Mobile Phone Shop            Donut Shop            Nail Salon
# 1              Pharmacy              Dive Bar             BBQ Joint
# 2    Seafood Restaurant           Salad Place          Cocktail Bar
# 3               Theater        Sandwich Place    Seafood Restaurant
# 4        Sandwich Place               Dog Run           Coffee Shop
#
#   10th Most Common Venue
# 0   Fast Food Restaurant
# 1                Dog Run
# 2       Department Store
# 3                Dog Run
# 4          Design Studio

# %% [markdown]
# ## Results

# %%
#Locate and show Cluster 0
cluster_0 = dallas_merged.loc[dallas_merged['Cluster Labels2'] == 0]
cluster_0
# Out:
#   Neighborhood   Latitude  Longitude  Cluster Labels2 1st Most Common Venue  \
# 1   The Cedars  32.769897 -96.785852                0            Skate Park
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 1            Food Court                Museum        History Museum
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 1           Art Gallery           Coffee Shop              Pharmacy
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 1              Dive Bar             BBQ Joint                Dog Run

# %%
#Locate and show Cluster 1
cluster_1 = dallas_merged.loc[dallas_merged['Cluster Labels2'] == 1]
cluster_1
# Out:
#              Neighborhood   Latitude  Longitude  Cluster Labels2  \
# 3    Dallas Arts District  32.788885 -96.798924                1
# 4   Dallas Farmers Market  32.778543 -96.788246                1
# 5              Deep Ellum  32.784001 -96.778559                1
# 10             South Side  32.765736 -96.794980                1
# 12                 Uptown  32.802121 -96.800784                1
#
#    1st Most Common Venue  2nd Most Common Venue 3rd Most Common Venue  \
# 3             Food Truck  Performing Arts Venue            Steakhouse
# 4    American Restaurant         Farmers Market            Food Truck
# 5                    Bar              BBQ Joint           Music Venue
# 10           Music Venue                    Bar   American Restaurant
# 12          Cocktail Bar                    Bar    Seafood Restaurant
#
#     4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 3     American Restaurant   Japanese Restaurant            Art Museum
# 4   Vietnamese Restaurant                  Pool          Dessert Shop
# 5     American Restaurant    Mexican Restaurant          Dessert Shop
# 10            Coffee Shop             Rock Club      Business Service
# 12            Pizza Place                  Café                   Gym
#
#    7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 3                Theater        Sandwich Place    Seafood Restaurant
# 4         Sandwich Place               Dog Run           Coffee Shop
# 5               Dive Bar           Coffee Shop           Art Gallery
# 10           Record Shop                   Pub          Cocktail Bar
# 12    Italian Restaurant          Burger Joint        Breakfast Spot
#
#    10th Most Common Venue
# 3                 Dog Run
# 4           Design Studio
# 5             Pizza Place
# 10      Convenience Store
# 12     Salon / Barbershop

# %%
#Locate and show Cluster 2
cluster_2 = dallas_merged.loc[dallas_merged['Cluster Labels2'] == 2]
cluster_2
# Out:
#           Neighborhood   Latitude  Longitude  Cluster Labels2  \
# 9  Riverfront District  32.768468 -96.812929                2
#
#   1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 9          Liquor Store             BBQ Joint             Nightclub
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 9               Gay Bar      Business Service         Design Studio
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 9              Dive Bar        Discount Store                 Diner
#
#   10th Most Common Venue
# 9           Dessert Shop

# %%
#Locate and show Cluster 3
cluster_3 = dallas_merged.loc[dallas_merged['Cluster Labels2'] == 3]
cluster_3
# Out:
#       Neighborhood   Latitude  Longitude  Cluster Labels2  \
# 6  Design District  32.789055  -96.82159                3
#
#   1st Most Common Venue   2nd Most Common Venue 3rd Most Common Venue  \
# 6           Art Gallery  Furniture / Home Store          Antique Shop
#
#   4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 6    Mexican Restaurant     Convenience Store        Shipping Store
#
#   7th Most Common Venue 8th Most Common Venue 9th Most Common Venue  \
# 6               Brewery           Pizza Place            Steakhouse
#
#   10th Most Common Venue
# 6            Bridal Shop

# %%
#Locate and show Cluster 4
cluster_4 = dallas_merged.loc[dallas_merged['Cluster Labels2'] == 4]
cluster_4
# Out:
#                       Neighborhood   Latitude  Longitude  Cluster Labels2  \
# 0                  Baylor District  32.797826 -96.778186                4
# 2            Civic Center District  32.776255 -96.798500                4
# 7             Main Street District  32.780931 -96.798114                4
# 8                 Reunion District  32.773613 -96.807676                4
# 11  Thanksgiving Commercial Center  32.784866 -96.796783                4
# 13                    Victory Park  32.788206 -96.810155                4
# 14      West End Historic District  32.780877 -96.807525                4
#
#    1st Most Common Venue 2nd Most Common Venue 3rd Most Common Venue  \
# 0            Pizza Place        Discount Store        Sandwich Place
# 2                  Hotel           Coffee Shop                   Bar
# 7                  Hotel           Coffee Shop    Mexican Restaurant
# 8                  Hotel   American Restaurant        Scenic Lookout
# 11                   Gym           Coffee Shop          Cocktail Bar
# 13            Restaurant                Lounge            Sports Bar
# 14        History Museum        Sandwich Place                 Plaza
#
#    4th Most Common Venue 5th Most Common Venue 6th Most Common Venue  \
# 0     Mexican Restaurant            Taco Place         Grocery Store
# 2                   Café                 Plaza           IT Services
# 7         Sandwich Place                   Bar          Cocktail Bar
# 8                  Plaza                   Bar            Restaurant
# 11    Italian Restaurant                 Hotel            Steakhouse
# 13                   Bar           Yoga Studio          Cocktail Bar
# 14                 Hotel           Music Venue          Liquor Store
#
#    7th Most Common Venue    8th Most Common Venue 9th Most Common Venue  \
# 0      Mobile Phone Shop               Donut Shop            Nail Salon
# 2     Seafood Restaurant              Salad Place          Cocktail Bar
# 7            Salad Place                     Park                  Café
# 8            Event Space              Coffee Shop           Beer Garden
# 11            Taco Place  New American Restaurant              Boutique
# 13      Ramen Restaurant   Furniture / Home Store           Pizza Place
# 14              Pharmacy              Coffee Shop     Convenience Store
#
#    10th Most Common Venue
# 0    Fast Food Restaurant
# 2        Department Store
# 7              Sports Bar
# 8              Food Truck
# 11         Sandwich Place
# 13               Pharmacy
# 14                 Lounge

# %%
# Create clusters map of downtown Dallas
map_clusters = folium.Map(location=[32.7791, -96.8003], zoom_start=13)
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# Assign colors to cluster markers
markers_colors = []
for lat, lon, poi, cluster in zip(dallas_merged['Latitude'], dallas_merged['Longitude'], \
    dallas_merged['Neighborhood'], dallas_merged['Cluster Labels2']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
